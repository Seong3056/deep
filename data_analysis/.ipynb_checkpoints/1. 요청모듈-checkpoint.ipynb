# %%
import requests as rq

# %% [markdown]
# # requests로 웹페이지 접속

# %%
url = "https://www.naver.com/"

rq.get(url)
# Out:
# <Response [200]>

# %%
rq.post(url)
# Out:
# <Response [200]>

# %%
# 없는 url주소에 요청을 보내면
url = "https://www.naver.com/a"

res = rq.get(url)

# 응답코드 출력하기
print(res.status_code)
# Out:
# 404

# %%
# 응답코드를 활용한 조건분기
def url_check(url):
    res = rq.get(url)
    
    print(res)
    
    sc = res.status_code
    
    if sc == 200:
        print(f"{url} 요청 성공")
        
    elif sc == 404:
        print(f"{url} 찾을 수 없음")
        
    else :
        print(f"{url} 알 수 없는 에러 : {sc}")

# %%
url_check("https://www.naver.com/")
# Out:
# <Response [200]>
# https://www.naver.com/ 요청 성공

# %%
url_check("https://www.naver.com/a")
# Out:
# <Response [404]>
# https://www.naver.com/a 찾을 수 없음

# %%
# 해더 가져오기
url = "https://www.anver.com/"

res = rq.get(url)

print(res)
print(res.headers)
# Out:
# <Response [200]>
# {'Date': 'Thu, 18 Jan 2024 07:26:33 GMT', 'Server': 'Apache', 'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Cache-Control': 'no-store, no-cache, must-revalidate', 'Pragma': 'no-cache', 'Link': '<https://anver.com/wp-json/>; rel="https://api.w.org/", <https://anver.com/wp-json/wp/v2/pages/4675>; rel="alternate"; type="application/json", <https://anver.com/>; rel=shortlink', 'Set-Cookie': 'PHPSESSID=o84k9ob4apoehkociel4q8b12a; path=/', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Transfer-Encoding': 'chunked', 'Content-Type': 'text/html; charset=UTF-8'}

# %%
# html코드 보기
print(res.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#">
# <![endif]-->
# <!--[if !(IE 7) & !(IE 8)]><!-->
# <html dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#">
# <!--<![endif]-->
# <head>
# 	<meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">
#
# 	<link rel="profile" href="http://gmpg.org/xfn/11">
# 	<link rel="pingback" href="https://anver.com/xmlrpc.php">
#
# <link rel="stylesheet" href="https://anver.com/wp-content/themes/anver/bootstrap/css/bootstrap.min.css" type="text/css" media="screen" />
# <link rel="stylesheet" href="https://anver.com/wp-content/themes/anver/style-main.css" type="text/css" media="screen" />
# ...

# %%
# 바이너리 형태로 값을 가져오기 때문에 res.text에서 한글이 깨지는 현상을 방지할 수 있음
print(res.content)
# Out:
# b'<!DOCTYPE html>\n<!--[if IE 7]>\n<html class="ie ie7" dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#">\n<![endif]-->\n<!--[if IE 8]>\n<html class="ie ie8" dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#">\n<![endif]-->\n<!--[if !(IE 7) & !(IE 8)]><!-->\n<html dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#">\n<!--<![endif]-->\n<head>\n\t<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n\t\n\t<link rel="profile" href="http://gmpg.org/xfn/11">\n\t<link rel="pingback" href="https://anver.com/xmlrpc.php">\n\n<link rel="stylesheet" href="https://anver.com/wp-content/themes/anver/bootstrap/css/bootstrap.min.css" type="text/css" media="screen" />\n<link rel="stylesheet" href="https://anver.com/wp-content/themes/anver/style-main.css" type="text/css" media="screen" />\n<link rel="stylesheet" type="text/css" media="print" href="https://anver.com/wp-content/themes/anver/print.css" />\n\t\n\t<
# ...

# %%
# 인코딩 확인
res.encoding
# Out:
# 'UTF-8'

# %%
# 쿼리스트링 데이터 생성
res = rq.get(url, params = {"key1" : "value1", "key2" : "value2"})

# %% [markdown]
# # urllib  으로 웹페이지 접속

# %%
from urllib.request import urlopen

# %%
url = "https://www.naver.com/"

page = urlopen(url) # 요청 객체를 이용해 요청

print(page)

# %%
print(page.code)
print(page.headers)
print(page.url)
print(page.info().get_content_charset())
# Out:
# 200
# Server: NWS
# Date: Thu, 18 Jan 2024 07:26:56 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: close
# Set-Cookie: PM_CK_loc=5840a8bb685fa0cd97809183cbad4a09202b409e52de09c2b8f4d8135aa5e5b5; Expires=Fri, 19 Jan 2024 07:26:56 GMT; Path=/; HttpOnly
# Cache-Control: no-cache, no-store, must-revalidate
# Pragma: no-cache
# X-Frame-Options: DENY
# X-XSS-Protection: 1; mode=block
# Strict-Transport-Security: max-age=63072000; includeSubdomains
# Referrer-Policy: unsafe-url
#
#
# https://www.naver.com/
# utf-8

# %%
# requests의 content()상수와 동일한 기능
print(page.read())
# Out:
# b'   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x
# ...
